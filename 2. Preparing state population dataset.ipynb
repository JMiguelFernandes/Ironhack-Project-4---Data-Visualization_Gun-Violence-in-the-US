# %% [markdown]
# ## Cleaning census data
#
# I only want the population by state between 2013 and 2018 (the period for which I have gun incident data). Everything else I discarded. I only included the data for the 50 states (+DC), since I don't have gun incident data for the other American territories like Puerto Rico or Guam.
#
# I wrote the reduced data to a csv file in the data_clean folder.

# %%
import pandas as pd

# %%
pop = pd.read_csv("data_raw/nst-est2019-alldata.csv")

# %%
pop
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 0       10      0        0      0         United States      308745538
# 1       20      1        0      0      Northeast Region       55317240
# 2       20      2        0      0        Midwest Region       66927001
# 3       20      3        0      0          South Region      114555744
# 4       20      4        0      0           West Region       71945553
# 5       40      3        6      1               Alabama        4779736
# 6       40      4        9      2                Alaska         710231
# 7       40      4        8      4               Arizona        6392017
# 8       40      3        7      5              Arkansas        2915918
# 9       40      4        9      6            California       37253956
# 10      40      4        8      8              Colorado        5029196
# 11      40      1        1      9           Connecticut        3574097
# ...

# %%
pop.loc[[i for i in range(5, 56)], ["NAME", 
     "POPESTIMATE2013", 
     "POPESTIMATE2014", 
     "POPESTIMATE2015", 
     "POPESTIMATE2016", 
     "POPESTIMATE2017", 
     "POPESTIMATE2018"]].to_csv("data_clean/pop_by_state_and_year.csv", index = False)
